# %% [markdown]
# ## Análisis de publicaciones de ofertas laborales en Linkedin.
#
# ### Desarrolle el notebook incorporando los siguientes puntos.
#
# Presentación en clase del 14/12/2023.
#
# Link de referencia: https://www.kaggle.com/datasets/arshkon/linkedin-job-postings
#
# Se debe desarrollar:
# - Descripción de los datos, incorporando breve descripción y si corresponde a una variable cuantitativa (ej: 1.5, 2.3, 10) o cualitativa (ej: 1, 3, A, Rojo).
# - Planteamiento de al menos 5 (nota 6 max) preguntas de interés a desarrollar.
# - Desarrollo al menos 4 (nota 6 max) tipos de gráficos distintos.
# - Construcción de nuevas variables en **caso de ser necesario**.
# - Desarrollo e interpretación de los gráficos en base a las preguntas de interés.
# - Los gráficos deben contener las leyendas y títulos correspondientes.
# - Paleta de colores definida y ser consistentes en los colores.
# -   Metrica Clicks - Linea Naranja
#     Metas Clicks - Linea Gris
#     Metrica Ventas - Linea Naranja -> Verde
#     Metas Ventas - Linea Gris
# - Se deben agregar comentarios en la configuración de los gráficos.

# %%
import pandas as pd

url = 'https://drive.google.com/file/d/1Peh8b1MF0cp2ua3ir52ZxkHdW8Ft0aBD/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
#print(path)

df = pd.read_csv(path, sep=';', header=0, compression='zip')
df.tail(10)
# Out:
# https://drive.google.com/uc?export=download&id=1Peh8b1MF0cp2ua3ir52ZxkHdW8Ft0aBD
#           job_id  company_id  \
# 3756  3701373180     79098.0
# 3757  3701373187     79098.0
# 3758  3701373279      2701.0
# 3759  3701373292      2701.0
# 3760  3701373317  15259054.0
# 3761  3701373383     13651.0
# 3762  3701373385  18312164.0
# 3763  3701373427   1321042.0
# 3764  3701373493      5619.0
# 3765  3701373524      2623.0
#
#                                                   title  min_salary  \
# 3756                            Senior Systems Engineer    75000.00
# 3757                          Senior IT Project Manager   110000.00
# 3758                         Insurance Defense Attorney    70800.00
# 3759                         Insurance Defense Attorney    70800.00
# 3760  Equipment Maintenance Technician- Automotive P...       20.00
# 3761                                     Senior Analyst    75000.00
# 3762                                      Sales Manager    60000.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3766 entries, 0 to 3765
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      3766 non-null   int64
#  1   company_id                  3766 non-null   float64
#  2   title                       3766 non-null   object
#  3   min_salary                  3766 non-null   float64
#  4   pay_period                  3766 non-null   object
#  5   formatted_work_type         3766 non-null   object
#  6   location                    3766 non-null   object
#  7   applies                     3766 non-null   float64
#  8   remote_allowed              3766 non-null   float64
#  9   views                       3766 non-null   float64
#  10  formatted_experience_level  3766 non-null   object
#  11  sponsored                   3766 non-null   int64
#  12  company_size                3766 non-null   float64
# ...
